# %% [markdown]
# ### matplotlib

# %% [markdown]
# - pyplot 객체를 사용하여 데이터를 표시
# - pyplot 객체에 그래프들을 쌓은 다음 show로 flush

# %%
import matplotlib.pyplot as plt

X = range(100)
Y = [value**2 for value in X]
plt.plot(X, Y)
plt.show()

# %% [markdown]
# - 최대 단점 argument를 kwargs 받음
# - 고정된 argument가 없어서 alt + tab으로 확인이 어려움
#
# - Graph는 원래 figure 객체에 생성됨
# - pyplot 객체 사용 시, 기본 figure에 그래프가 그려짐

# %%
import numpy as np

X_1 = range(100)
Y_1 = [np.cos(value) for value in X]

X_2 = range(100)
Y_2 = [np.sin(value) for value in X]

plt.plot(X_1, Y_1)
plt.plot(X_2, Y_2)
plt.show()

# %%
fig = plt.figure()               # figure 반환
fig.set_size_inches(10, 5)       # 크기 지정
ax_1 = fig.add_subplot(1, 2, 1)  # 두 개의 plot 생성
ax_2 = fig.add_subplot(1, 2, 2)  # 두 개의 plot 생성

ax_1.plot(X_1, Y_1, c = "b")     # 첫번째 plot
ax_2.plot(X_2, Y_2, c = "g")     # 두번째 plot
plt.show()   # show & flush

# %% [markdown]
# ### Set color

# %% [markdown]
# - Color 속성을 사용
# - Float → 흑백, rgb color, predefined color 사용

# %%
X_1 = range(100)
Y_1 = [value for value in X]

X_2 = range(100)
Y_2 = [value + 100 for value in X]

plt.plot(X_1, Y_1, color = "#eeefff")
plt.plot(X_2, Y_2, color = "r")

plt.show()

# %% [markdown]
# ### Set linestyle

# %% [markdown]
# - ls 또는 linestyle 속성 사용

# %%
plt.plot(X_1, Y_1, color = "b", linestyle = "dashed")
plt.plot(X_2, Y_2, color = "r", ls = "dotted")

plt.show()

# %% [markdown]
# ### Set title

# %% [markdown]
# - Pyplot에 title 함수 사용
# - figure의 subplot별 입력 가능

# %%
plt.plot(X_1, Y_1, color = "b", linestyle = "dashed")
plt.plot(X_2, Y_2, color = "r", linestyle = "dotted")

plt.title("Two lines")
plt.show()

# %% [markdown]
# - Latex 타입의 표현도 가능(수식 표현 가능)

# %%
plt.plot(X_1, Y_1, color = "b", linestyle = "dashed")
plt.plot(X_2, Y_2, color = "r", linestyle = "dotted")

plt.title("$y = \\frac{ax + b}{test}$")
plt.xlabel('$x_line$')
plt.ylabel('y_line')
plt.show()

# %%
plt.plot(X_1, Y_1, color = "b", linestyle = "dashed")
plt.plot(X_2, Y_2, color = "r", linestyle = "dotted")

plt.text(50, 70, "Line_1")   # 해당 좌표 위치에 Text를 넣는 것
plt.annotate('line_2', xy = (50, 150), xytext = (20, 175), 
             arrowprops = dict(facecolor = 'black', shrink = 0.05))

plt.title("$y = \\frac{ax + b}{test}$")
plt.xlabel('$x_line$')
plt.ylabel('y_line')

plt.show()

# %% [markdown]
# ### Set legend

# %% [markdown]
# - Legend 함수로 범례를 표시함
# - loc 위치 등 속성 지정

# %%
plt.plot(X_1, Y_1, color = "b", linestyle = "dashed", label = 'line_1')
plt.plot(X_2, Y_2, color = "r", linestyle = "dotted", label = 'line_2')

plt.legend(shadow = True, fancybox = True, loc = "lower right")
plt.show()

# %% [markdown]
# ### Set grid & xylim

# %% [markdown]
# - Graph 보조선을 긋는 grid와 xy축 범위 한계를 지정

# %%
plt.plot(X_1, Y_1, color = "b", linestyle = "dashed", label = 'line_1')
plt.plot(X_2, Y_2, color = "r", linestyle = "dotted", label = 'line_2')

plt.legend(shadow = True, fancybox = True, loc = "lower right")
plt.grid(True, lw = 0.4, ls = '--', c = '.90')
plt.xlim(-100, 200)
plt.ylim(-200, 200)
plt.show()

# %% [markdown]
# ### savefig

# %%
plt.plot(X_1, Y_1, color = "b", linestyle = "dashed", label = 'line_1')
plt.plot(X_2, Y_2, color = "r", linestyle = "dotted", label = 'line_2')

plt.legend(shadow = True, fancybox = True, loc = "lower right")
plt.grid(True, lw = 0.4, ls = '--', c = '.90')
plt.xlim(-100, 200)
plt.ylim(-200, 200)
plt.savefig('test.png', c = 'a')
plt.show()
# Out:
# C:\Users\PC\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "c" which is no longer supported as of 3.3 and will become an error two minor releases later

# %% [markdown]
# ### Scatter

# %% [markdown]
# - scatter 함수 사용
# - marker : scatter 모양 지정

# %%
data_1 = np.random.rand(512, 2)   # 512 x 2 shape data
data_2 = np.random.rand(512, 2)   # 512 x 2 shape data

plt.scatter(data_1[:, 0], data_1[:, 1], c = 'b', marker = 'x')
plt.scatter(data_2[:, 0], data_2[:, 1], c = 'r', marker = '^')

plt.show()

# %% [markdown]
# - s : 데이터의 크기를 지정
# - 데이터의 크기 비교 가능

# %%
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N)) ** 2
plt.scatter(x, y, s = area, c = colors, alpha = 0.5)

plt.show()

# %% [markdown]
# ### Bar chart

# %% [markdown]
# - Bar 함수 사용

# %%
data = [[5., 25., 50., 20.],
        [4., 23., 51., 17],
        [6., 22., 52., 19]]

X = np.arange(4)
plt.bar(X + 0.00, data[0], color = 'b', width = 0.25)
plt.bar(X + 0.25, data[1], color = 'g', width = 0.25)
plt.bar(X + 0.50, data[2], color = 'r', width = 0.25)
plt.xticks(X + 0.25, ("A", "B", "C", "D"))
plt.show()

# %%
data = np.array([[5., 25., 50., 20.],
                 [4., 23., 51., 17],
                 [6., 22., 52., 19]])

color_list = ['b', 'g', 'r']
data_label = ['A', 'B', 'C']
X = np.arange(data.shape[1])
for i in range(data.shape[0]):
    plt.bar(X, data[i], bottom = np.sum(data[:i], axis = 0),   # bar chart를 세로로 쌓을 때 "bottom"(기준선)이 중요★
            color = color_list[i], label = data_label[i])
plt.legend()
plt.show()

# %%
A = [5., 30., 45., 22.]
B = [5, 25, 50, 20]

X = range(4)

plt.bar(X, A, color = 'b')
plt.bar(X, B, color = 'r', bottom = 60)
plt.show()

# %%
# Population 나타낼 때 많이 쓰는 horizontal bar chart

women_pop = np.array([5, 30, 45, 22])
men_pop = np.array([5, 25, 50, 20])
X = np.arange(4)

plt.barh(X, women_pop, color = 'r')
plt.barh(X, -men_pop, color = 'b')
plt.show()

# %% [markdown]
# ### histogram

# %%
X = np.random.randn(1000)
plt.hist(X, bins = 100)    # bins는 데이터를 몇 개의 구간으로 나눌 것인지 결정하는 변수
plt.show()

# %% [markdown]
# ### boxplot

# %% [markdown]
# - 데이터를 전체적으로 볼 때 유용함
# - (ex) EDA할 때

# %%
data = np.random.randn(100, 5)   # 100 x 5 shape data
plt.boxplot(data)
plt.show()
