# %% [markdown]
# - wolframalpha.com 에서 그래프를 보기 원하는 식을 입력하여 직관적으로 보기 좋음

# %% [markdown]
# ### Cost Function

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### y = 1일 때 & y = 0일 때 모두를 고려한 Cost Function

# %% [markdown]
# ![1100.png](attachment:1100.png)

# %% [markdown]
# ### J(⍬) 미분한 값

# %% [markdown]
# ![1101.png](attachment:1101.png)

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %% [markdown]
# ### Sigmoid Function

# %%
def sigmoid(x):
    a = []
    for item in x:
        a.append(1 / (1 + math.exp(-item)))
    return a

x = np.arange(-10., 10., 0.2)
sig = sigmoid(x)
plt.plot(x, sig)
plt.show()

# %% [markdown]
# ### Odds Ratio

# %%
p = np.arange(0., 1., 0.01)
odds = p / (1 - p)
plt.plot(p, odds)
plt.show()

# %%
def log_odds(p):
    return np.log(p / (1 - p))

x = np.arange(0.005, 1, 0.005)
log_odds_x = log_odds(x)

plt.plot(x, log_odds_x)
plt.ylim(-8, 8)
plt.xlabel('x')
plt.ylabel('log_odds(x)')

# y axis ticks and gridline
plt.yticks([-7, 0, 7])
ax = plt.gca()                   # plt.gca()로 현재의 Axes를 반환
ax.yaxis.grid(True)

plt.tight_layout()
plt.show()

# %%
x = np.arange(0.005, 1, 0.005)
y = - np.log(1 - x)
plt.plot(x, y)
plt.show()

# %%
x = np.arange(0.005, 1, 0.005)
y = - np.log(x)
plt.plot(x, y)
plt.show()
